# %%
import numpy as np
import torch
import pandas as pd
import odbo
import os

# %% [markdown]
# ## Get initial experiment design

# %%
# Load dataset
random_seed = 8
np.random.seed(random_seed)
data_test = pd.read_csv('../datasets/GB1_2016_149361.csv', sep=',')
name_pre, Y_test = np.array(data_test['AACombo']), np.array(data_test['Fitness'])
shuffle_order = np.arange(len(Y_test))
np.random.shuffle(shuffle_order[1:])
name_pre[1:], Y_test[1:] = name_pre[shuffle_order[1:]], Y_test[shuffle_order[1:]]
name = odbo.utils.code_to_array(name_pre)
if os.path.isfile('sele_experiment_GB1_2016.npy') == True:
    name_sele = np.load('sele_experiment_GB1_2016.npy')
    Y_train = np.load('sele_fitness_GB1_2016.npy')
    print('Selected initial experiments no. is ', len(Y_train))
else:
    # Let each site has 20 AA codes at least show up twice 
    sele_indices = odbo.initialization.initial_design(name, least_occurance=[2,2,2,2],verbose = False,random_state=random_seed)
    # Initial experiments are selected to be name_sele with fitness of Y_sele
    name_sele, Y_train = name[sele_indices, :], Y_test[sele_indices]
    print('Selected initial experiments no. is ', len(sele_indices))
print('Select max Y: ', Y_train.max())
# Out:
# Selected initial experiments no. is  40
# Select max Y:  1.320616068

# %% [markdown]
# ## Transform AA codes to average fitness feature

# %%
# Using Max measurement results as initial features
threshold = max(0.05, np.mean(Y_train)-2*np.std(Y_train))
feature_model = odbo.featurization.MaxMeasurement(raw_vars=name_sele, Y=Y_train)
X_train = feature_model.transform(name_sele)
X_test = feature_model.transform(name)

# %% [markdown]
# ## Random selection

# %%
sele_Y = list(np.random.choice(Y_test, 50, replace = False))
Y_train_sele = list(Y_train.copy())
Y_train_sele.extend(sele_Y)
print('Max Y', max(sele_Y))
np.save('results/GB1_2016/GB1_2016_random_{}.npy'.format(random_seed), Y_train_sele)
# Out:
# Max Y 3.978361133

# %% [markdown]
# ## Naive BO

# %%
X_train_sele, Y_train_sele = torch.tensor(X_train), torch.tensor(Y_train.reshape(len(Y_train),1))
X_test_sele, Y_test_sele = torch.tensor(X_test), torch.tensor(Y_test.reshape(len(Y_test),1))
search_name_sele, name_sele_temp = name, name_sele

l, search_iter = 0, 50
gp_method='gp_regression'
batch_size = 1
failure_count = 0

while l < search_iter:
    print("Iter: ", l, "Current Max: ", Y_train_sele.max().detach().numpy(), "Test max: ", Y_test_sele.max().detach().numpy())
    X_next, acq_value, next_exp_id = odbo.bo_design(X=X_train_sele, Y=Y_train_sele, X_pending=X_test_sele, gp_method=gp_method, batch_size=batch_size)
    ids_keep = list(np.delete(range(X_test_sele.shape[0]), next_exp_id))
    X_train_sele, Y_train_sele = torch.cat([X_train_sele, X_test_sele[next_exp_id, :]]), torch.cat([Y_train_sele, Y_test_sele[next_exp_id]])
    X_test_sele, Y_test_sele = X_test_sele[ids_keep, :], Y_test_sele[ids_keep]
    name_sele_temp = np.concatenate((name_sele_temp, search_name_sele[next_exp_id]))
    search_name_sele = search_name_sele[ids_keep]
    feature_model1 = odbo.featurization.MaxMeasurement(raw_vars=X_train_sele, Y=Y_train_sele.detach().numpy())
    print("Newly added value: ", Y_train_sele[-batch_size:].detach().numpy(), name_sele_temp[-1])
    if Y_train_sele[-batch_size:].detach().numpy().max() <= Y_train_sele[:-batch_size].max():
        failure_count = failure_count + 1
    else:
        failure_count = 0
    if failure_count >= 3 and max_count < 3:
        max_count = max_count + 1
        feature_model1 = odbo.featurization.AvgMeasurement(raw_vars=X_train_sele, Y=Y_train_sele.detach().numpy())
    else:
        max_count = 0
    X_train_sele = torch.tensor(feature_model1.transform(X_train_sele))
    X_test_sele= torch.tensor(feature_model1.transform(X_test_sele))
    l = l + 1
np.save('results/GB1_2016/GB1_2016_BO_GP_batch1_{}.npy'.format(random_seed), Y_train_sele)
# Out:
# Iter:  0 Current Max:  1.320616068 Test max:  8.761965656
# Newly added value:  [[0.31354108]] ['Q' 'V' 'G' 'A']
# Iter:  1 Current Max:  1.320616068 Test max:  8.761965656
# Newly added value:  [[0.00384758]] ['Q' 'D' 'A' 'V']
# Iter:  2 Current Max:  1.320616068 Test max:  8.761965656
# Newly added value:  [[0.01078996]] ['Q' 'V' 'A' 'V']
# Iter:  3 Current Max:  1.320616068 Test max:  8.761965656
# Newly added value:  [[0.66989285]] ['Q' 'D' 'A' 'A']
# Iter:  4 Current Max:  1.320616068 Test max:  8.761965656
# Newly added value:  [[4.50273083]] ['V' 'V' 'A' 'A']
# Iter:  5 Current Max:  4.502730826 Test max:  8.761965656
# Newly added value:  [[4.15798313]] ['V' 'D' 'A' 'A']
# Iter:  6 Current Max:  4.502730826 Test max:  8.761965656
# Newly added value:  [[1.76143518]] ['V' 'V' 'G' 'A']
# Iter:  7 Current Max:  4.502730826 Test max:  8.761965656
# Newly added value:  [[0.35189879]] ['V' 'V' 'A' 'V']
# Iter:  8 Current Max:  4.502730826 Test max:  8.761965656
# Newly added value:  [[4.682612]] ['V' 'I' 'A' 'A']
# Iter:  9 Current Max:  4.682612 Test max:  8.761965656
# Newly added value:  [[6.12380479]] ['V' 'W' 'A' 'A']
# Iter:  10 Current Max:  6.123804795 Test max:  8.761965656
# Newly added value:  [[1.]] ['V' 'D' 'G' 'V']
# Iter:  11 Current Max:  6.123804795 Test max:  8.761965656
# Newly added value:  [[0.00256153]] ['K' 'H' 'H' 'R']
# Iter:  12 Current Max:  6.123804795 Test max:  8.761965656
# Newly added value:  [[5.15691841]] ['V' 'Y' 'A' 'A']
# Iter:  13 Current Max:  6.123804795 Test max:  8.761965656
# Newly added value:  [[2.01352185]] ['V' 'W' 'G' 'A']
# Iter:  14 Current Max:  6.123804795 Test max:  8.761965656
# Newly added value:  [[0.06134717]] ['Q' 'Y' 'A' 'A']
# Iter:  15 Current Max:  6.123804795 Test max:  8.761965656
# Newly added value:  [[0.25285153]] ['V' 'W' 'A' 'V']
# Iter:  16 Current Max:  6.123804795 Test max:  8.761965656
# Newly added value:  [[0.01109053]] ['L' 'M' 'V' 'A']
# Iter:  17 Current Max:  6.123804795 Test max:  8.761965656
# Newly added value:  [[0.00432763]] ['T' 'N' 'I' 'L']
# Iter:  18 Current Max:  6.123804795 Test max:  8.761965656
# Newly added value:  [[0.01054167]] ['R' 'C' 'K' 'E']
# Iter:  19 Current Max:  6.123804795 Test max:  8.761965656
# Newly added value:  [[0.01522685]] ['Y' 'W' 'C' 'N']
# Iter:  20 Current Max:  6.123804795 Test max:  8.761965656
# Newly added value:  [[3.62904744]] ['F' 'R' 'G' 'A']
# Iter:  21 Current Max:  6.123804795 Test max:  8.761965656
# Newly added value:  [[4.24854222]] ['F' 'R' 'A' 'A']
# Iter:  22 Current Max:  6.123804795 Test max:  8.761965656
# Newly added value:  [[8.76196566]] ['F' 'W' 'A' 'A']
# Iter:  23 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.]] ['Q' 'W' 'T' 'K']
# Iter:  24 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.01069995]] ['I' 'H' 'G' 'R']
# Iter:  25 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.00224659]] ['E' 'G' 'Q' 'F']
# Iter:  26 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.]] ['I' 'G' 'Q' 'F']
# Iter:  27 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.01370417]] ['A' 'E' 'V' 'V']
# Iter:  28 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.0116137]] ['N' 'H' 'I' 'P']
# Iter:  29 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.00775708]] ['D' 'Q' 'S' 'L']
# Iter:  30 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.0020454]] ['G' 'D' 'S' 'C']
# Iter:  31 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.00575]] ['Y' 'Y' 'L' 'F']
# Iter:  32 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.00476667]] ['L' 'P' 'A' 'I']
# Iter:  33 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.00544536]] ['N' 'A' 'F' 'C']
# Iter:  34 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.00906061]] ['V' 'P' 'T' 'I']
# Iter:  35 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.00622917]] ['A' 'L' 'C' 'E']
# Iter:  36 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.0016242]] ['K' 'K' 'V' 'M']
# Iter:  37 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.]] ['F' 'M' 'Q' 'G']
# Iter:  38 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.00652579]] ['C' 'K' 'Q' 'F']
# Iter:  39 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.00360636]] ['H' 'F' 'F' 'E']
# Iter:  40 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.00841894]] ['I' 'N' 'L' 'Y']
# Iter:  41 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.00143951]] ['W' 'A' 'N' 'E']
# Iter:  42 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.00522064]] ['C' 'W' 'I' 'N']
# Iter:  43 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.03073246]] ['L' 'C' 'W' 'A']
# Iter:  44 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.00331019]] ['M' 'R' 'H' 'L']
# Iter:  45 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.01827222]] ['T' 'H' 'Y' 'P']
# Iter:  46 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.01827222]] ['A' 'A' 'V' 'E']
# Iter:  47 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.00388916]] ['I' 'F' 'I' 'T']
# Iter:  48 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.]] ['E' 'F' 'I' 'T']
# Iter:  49 Current Max:  8.761965656 Test max:  8.045152004
# Newly added value:  [[0.]] ['F' 'E' 'D' 'A']

# %% [markdown]
# ## TuRBO

# %%
X_train_sele, Y_train_sele = torch.tensor(X_train), torch.tensor(Y_train.reshape(len(Y_train),1))
search_name_sele, name_sele_temp = name, name_sele
X_test_sele, Y_test_sele = torch.tensor(X_test), torch.tensor(Y_test.reshape(len(Y_test),1))

l, search_iter = 0, 50
gp_method='gp_regression'
tr_length = [3.2]
batch_size = 1
failure_count = 0

state = odbo.turbo.TurboState(dim=X_train_sele.shape[1], batch_size=batch_size, length=tr_length, n_trust_regions=len(tr_length), failure_tolerance = 10)
state.best_value = Y_train_sele.max()
while l < search_iter:
    print("Iter: ", l, "Current Max: ", Y_train_sele.max().detach().numpy(), 'TR length: ', state.length, "Test max: ", Y_test_sele.max().detach().numpy())
    X_next, acq_value, raw_next_exp_id = odbo.turbo_design(state=state, X=X_train_sele, Y=Y_train_sele, X_pending=X_test_sele, n_trust_regions=len(tr_length), batch_size=batch_size, gp_method=gp_method)
    Y_next_m = torch.zeros((len(tr_length), batch_size, 1), device=Y_train_sele.device, dtype=Y_train_sele.dtype)
    next_exp_id = []
    for i in range(batch_size):
        next_exp_id_m = raw_next_exp_id[:, i]
        Y_next_m[:, i, 0], idtoadd = Y_test_sele[next_exp_id_m].reshape(len(tr_length)), next_exp_id_m[np.argmax(Y_test_sele[next_exp_id_m])]
        next_exp_id.append(idtoadd)
    X_train_sele, Y_train_sele = torch.cat([X_train_sele, X_test_sele[next_exp_id, :]]), torch.cat([Y_train_sele, Y_test_sele[next_exp_id]])
    ids_keep = list(np.delete(range(X_test_sele.shape[0]), next_exp_id))
    X_test_sele, Y_test_sele = X_test_sele[ids_keep, :], Y_test_sele[ids_keep]
    name_sele_temp = np.concatenate((name_sele_temp, search_name_sele[next_exp_id]))
    search_name_sele = search_name_sele[ids_keep]
    state = odbo.turbo.update_state(state=state, Y_next=Y_next_m)
    feature_model1 = odbo.featurization.AvgMeasurement(raw_vars=X_train_sele, Y=Y_train_sele.detach().numpy())
    print("Newly added value: ", Y_train_sele[-batch_size:].detach().numpy(), name_sele_temp[-1])

    if Y_train_sele[-batch_size:].detach().numpy().max() <= Y_train_sele[:-batch_size].max():
        failure_count = failure_count + 1
    else:
        failure_count = 0
    if failure_count >= 3 and max_count < 3:
        max_count = max_count + 1
        feature_model1 = odbo.featurization.MaxMeasurement(raw_vars=X_train_sele, Y=Y_train_sele.detach().numpy())
    else:
        max_count = 0
    X_train_sele = torch.tensor(feature_model1.transform(X_train_sele))
    X_test_sele= torch.tensor(feature_model1.transform(X_test_sele))
    l = l + 1

np.save('results/GB1_2016/GB1_2016_TuRBO_GP_batch1_{}.npy'.format(random_seed), Y_train_sele)
# Out:
# Iter:  0 Current Max:  1.320616068 TR length:  [3.2] Test max:  8.761965656
# Newly added value:  [[0.31354108]] ['Q' 'V' 'G' 'A']
# Iter:  1 Current Max:  1.320616068 TR length:  [3.2] Test max:  8.761965656
# Newly added value:  [[0.12057613]] ['V' 'D' 'A' 'V']
# Iter:  2 Current Max:  1.320616068 TR length:  [3.2] Test max:  8.761965656
# Newly added value:  [[0.01078996]] ['Q' 'V' 'A' 'V']
# Iter:  3 Current Max:  1.320616068 TR length:  [3.2] Test max:  8.761965656
# Newly added value:  [[0.66989285]] ['Q' 'D' 'A' 'A']
# Iter:  4 Current Max:  1.320616068 TR length:  [3.2] Test max:  8.761965656
# Iter 10/500: 1.5446513738095973
# Iter 20/500: 1.4153160039662027
# Iter 30/500: 1.2045239509092989
# Iter 40/500: -0.3578078307775326
# Iter 50/500: -0.3759927166049044
# Iter 60/500: -0.3769269174103771
# Iter 70/500: -0.37760742971329414
# The scipy optimizer and minimum inferred noises cannot make the kernel PSD, switch to torch optimizer
# Newly added value:  [[4.50273083]] ['V' 'V' 'A' 'A']
# Iter:  5 Current Max:  4.502730826 TR length:  [3.2] Test max:  8.761965656
# Newly added value:  [[1.76143518]] ['V' 'V' 'G' 'A']
# Iter:  6 Current Max:  4.502730826 TR length:  [3.2] Test max:  8.761965656
# Newly added value:  [[4.15798313]] ['V' 'D' 'A' 'A']
# Iter:  7 Current Max:  4.502730826 TR length:  [3.2] Test max:  8.761965656
# Newly added value:  [[1.]] ['V' 'D' 'G' 'V']
# Iter:  8 Current Max:  4.502730826 TR length:  [3.2] Test max:  8.761965656
# Newly added value:  [[0.00313021]] ['R' 'L' 'A' 'L']
# Iter:  9 Current Max:  4.502730826 TR length:  [3.2] Test max:  8.761965656
# Newly added value:  [[0.00367897]] ['C' 'A' 'I' 'Q']
# Iter:  10 Current Max:  4.502730826 TR length:  [3.2] Test max:  8.761965656
# Newly added value:  [[0.0304537]] ['F' 'C' 'Y' 'Q']
# Iter:  11 Current Max:  4.502730826 TR length:  [3.2] Test max:  8.761965656
# Newly added value:  [[0.00191667]] ['P' 'V' 'N' 'F']
# Iter:  12 Current Max:  4.502730826 TR length:  [3.2] Test max:  8.761965656
# Newly added value:  [[0.]] ['P' 'A' 'E' 'N']
# Iter:  13 Current Max:  4.502730826 TR length:  [3.2] Test max:  8.761965656
# Newly added value:  [[0.]] ['A' 'S' 'E' 'H']
# Iter:  14 Current Max:  4.502730826 TR length:  [3.2] Test max:  8.761965656
# Newly added value:  [[0.00691257]] ['W' 'G' 'Y' 'C']
# Iter:  15 Current Max:  4.502730826 TR length:  [1.6] Test max:  8.761965656
# Newly added value:  [[0.44220137]] ['L' 'V' 'A' 'T']
# Iter:  16 Current Max:  4.502730826 TR length:  [1.6] Test max:  8.761965656
# Newly added value:  [[0.04730372]] ['V' 'V' 'S' 'V']
# Iter:  17 Current Max:  4.502730826 TR length:  [1.6] Test max:  8.761965656
# Newly added value:  [[3.972931]] ['L' 'V' 'A' 'A']
# Iter:  18 Current Max:  4.502730826 TR length:  [1.6] Test max:  8.761965656
# Newly added value:  [[0.3179449]] ['L' 'V' 'M' 'V']
# Iter:  19 Current Max:  4.502730826 TR length:  [1.6] Test max:  8.761965656
# Newly added value:  [[0.]] ['Y' 'D' 'M' 'N']
# Iter:  20 Current Max:  4.502730826 TR length:  [1.6] Test max:  8.761965656
# Newly added value:  [[0.28069771]] ['L' 'D' 'L' 'V']
# Iter:  21 Current Max:  4.502730826 TR length:  [1.6] Test max:  8.761965656
# Newly added value:  [[0.03381548]] ['V' 'V' 'L' 'V']
# Iter:  22 Current Max:  4.502730826 TR length:  [1.6] Test max:  8.761965656
# Newly added value:  [[0.00384758]] ['Q' 'D' 'A' 'V']
# Iter:  23 Current Max:  4.502730826 TR length:  [1.6] Test max:  8.761965656
# Newly added value:  [[2.69846687]] ['V' 'L' 'A' 'A']
# Iter:  24 Current Max:  4.502730826 TR length:  [1.6] Test max:  8.761965656
# Newly added value:  [[1.37294933]] ['V' 'D' 'G' 'A']
# Iter:  25 Current Max:  4.502730826 TR length:  [0.8] Test max:  8.761965656
# Newly added value:  [[3.0900041]] ['L' 'D' 'A' 'A']
# Iter:  26 Current Max:  4.502730826 TR length:  [0.8] Test max:  8.761965656
# Newly added value:  [[0.00523182]] ['Q' 'M' 'L' 'P']
# Iter:  27 Current Max:  4.502730826 TR length:  [0.8] Test max:  8.761965656
# Newly added value:  [[2.31950253]] ['L' 'L' 'A' 'A']
# Iter:  28 Current Max:  4.502730826 TR length:  [0.8] Test max:  8.761965656
# Newly added value:  [[0.00288509]] ['P' 'Y' 'A' 'N']
# Iter:  29 Current Max:  4.502730826 TR length:  [0.8] Test max:  8.761965656
# Newly added value:  [[0.25267057]] ['I' 'C' 'F' 'C']
# Iter:  30 Current Max:  4.502730826 TR length:  [0.8] Test max:  8.761965656
# Newly added value:  [[0.00898384]] ['W' 'I' 'W' 'S']
# Iter:  31 Current Max:  4.502730826 TR length:  [0.8] Test max:  8.761965656
# Newly added value:  [[0.00755128]] ['Q' 'V' 'R' 'A']
# Iter:  32 Current Max:  4.502730826 TR length:  [0.8] Test max:  8.761965656
# Newly added value:  [[0.]] ['V' 'G' 'W' 'N']
# Iter:  33 Current Max:  4.502730826 TR length:  [0.8] Test max:  8.761965656
# Newly added value:  [[0.02353624]] ['R' 'H' 'Y' 'V']
# Iter:  34 Current Max:  4.502730826 TR length:  [0.8] Test max:  8.761965656
# Newly added value:  [[0.]] ['V' 'T' 'Q' 'F']
# Iter:  35 Current Max:  4.502730826 TR length:  [0.4] Test max:  8.761965656
# Newly added value:  [[1.2087645]] ['V' 'W' 'V' 'G']
# Iter:  36 Current Max:  4.502730826 TR length:  [0.4] Test max:  8.761965656
# Newly added value:  [[6.12380479]] ['V' 'W' 'A' 'A']
# Iter:  37 Current Max:  6.123804795 TR length:  [0.4] Test max:  8.761965656
# Newly added value:  [[6.02748855]] ['L' 'W' 'A' 'A']
# Iter:  38 Current Max:  6.123804795 TR length:  [0.4] Test max:  8.761965656
# Newly added value:  [[0.]] ['G' 'W' 'E' 'S']
# Iter:  39 Current Max:  6.123804795 TR length:  [0.4] Test max:  8.761965656
# Newly added value:  [[0.00607486]] ['R' 'N' 'G' 'Y']
# Iter:  40 Current Max:  6.123804795 TR length:  [0.4] Test max:  8.761965656
# Newly added value:  [[0.00288509]] ['F' 'G' 'F' 'K']
# Iter:  41 Current Max:  6.123804795 TR length:  [0.4] Test max:  8.761965656
# Newly added value:  [[2.74706776]] ['L' 'W' 'G' 'A']
# Iter:  42 Current Max:  6.123804795 TR length:  [0.4] Test max:  8.761965656
# Newly added value:  [[0.00251453]] ['Q' 'G' 'W' 'P']
# Iter:  43 Current Max:  6.123804795 TR length:  [0.4] Test max:  8.761965656
# Newly added value:  [[0.07187074]] ['M' 'Q' 'S' 'S']
# Iter:  44 Current Max:  6.123804795 TR length:  [0.4] Test max:  8.761965656
# Newly added value:  [[0.]] ['A' 'M' 'N' 'R']
# Iter:  45 Current Max:  6.123804795 TR length:  [0.4] Test max:  8.761965656
# Newly added value:  [[0.]] ['T' 'A' 'D' 'L']
# Iter:  46 Current Max:  6.123804795 TR length:  [0.4] Test max:  8.761965656
# Newly added value:  [[0.00231679]] ['Q' 'L' 'R' 'S']
# Iter:  47 Current Max:  6.123804795 TR length:  [0.2] Test max:  8.761965656
# Newly added value:  [[0.01387]] ['C' 'L' 'R' 'H']
# Iter:  48 Current Max:  6.123804795 TR length:  [0.2] Test max:  8.761965656
# Newly added value:  [[0.01705913]] ['N' 'N' 'F' 'T']
# Iter:  49 Current Max:  6.123804795 TR length:  [0.2] Test max:  8.761965656
# Newly added value:  [[0.00383333]] ['M' 'N' 'I' 'Y']
